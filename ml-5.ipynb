# %%
import timm
import os
import torch
import torch.nn as nn
import torch.optim as optim
import torchvision.transforms as transforms
from torch.utils.data import Dataset, DataLoader
from PIL import Image
import numpy as np
import matplotlib.pyplot as plt
import segmentation_models_pytorch as smp
from segmentation_models_pytorch.decoders.unet.model import UnetDecoder
from segmentation_models_pytorch.decoders.unet.model import SegmentationHead
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score
from sklearn.metrics import jaccard_score

import warnings
warnings.filterwarnings("ignore")
# Out:
# /opt/conda/lib/python3.9/site-packages/requests/__init__.py:102: RequestsDependencyWarning: urllib3 (1.26.9) or chardet (5.0.0)/charset_normalizer (2.0.12) doesn't match a supported version!
#   warnings.warn("urllib3 ({}) or chardet ({})/charset_normalizer ({}) doesn't match a supported "

# %%
class SegmentationDataset(Dataset):
    def __init__(self, image_dir, mask_dir, transform=None):
        self.image_dir = image_dir
        self.mask_dir = mask_dir
        self.transform = transform

        self.images = os.listdir(image_dir)
        self.masks = os.listdir(mask_dir)

    def __len__(self):
        return len(self.images)

    def __getitem__(self, idx):
        img_path = os.path.join(self.image_dir, self.images[idx])
        mask_path = os.path.join(self.mask_dir, self.images[idx].replace('.jpg', '.png'))


        image = Image.open(img_path).convert('RGB')
        mask = Image.open(mask_path).convert('L')


        if self.transform:
            image = self.transform(image)
            mask = self.transform(mask)

        return image, mask

data_transform = transforms.Compose([
    transforms.Resize((256, 256)),
    transforms.ToTensor(),
])

train_dataset = SegmentationDataset("leaf_disease_segmentation/train_images", "leaf_disease_segmentation/train_masks", transform=data_transform)
val_dataset = SegmentationDataset("leaf_disease_segmentation/valid_images", "leaf_disease_segmentation/valid_masks", transform=data_transform)

train_loader = DataLoader(train_dataset, batch_size=16, shuffle=True)
val_loader = DataLoader(val_dataset, batch_size=16, shuffle=False)

# %%
# encoder_names = ["resnet34", "resnet50", "resnet101", "vgg16", "vgg19", "densenet121", "densenet169", "efficientnet-b0", "efficientnet-b1", "efficientnet-b2", "efficientnet-b3", "efficientnet-b4", "efficientnet-b5", "efficientnet-b6", "efficientnet-b7"]
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# %%
def train_model(model, num_epochs, train_loader, val_loader, criterion, optimizer, model_save_path):
    best_val_loss = float("inf")

    for epoch in range(num_epochs):
        model.train()
        for images, masks in train_loader:
            images = images.to(device)
            masks = masks.to(device)

            optimizer.zero_grad()
            outputs = model(images)
            loss = criterion(outputs, masks)
            loss.backward()
            optimizer.step()

        model.eval()
        with torch.no_grad():
            val_loss = 0
            for images, masks in val_loader:
                images = images.to(device)
                masks = masks.to(device)

                outputs = model(images)
                loss = criterion(outputs, masks)
                val_loss += loss.item()

            val_loss /= len(val_loader)
            print(f"Epoch {epoch+1}/{num_epochs}, Loss: {loss.item()}, Validation Loss: {val_loss}")

            if val_loss < best_val_loss:
                print(f"Validation loss decreased from {best_val_loss:.4f} to {val_loss:.4f}, saving model...")
                torch.save(model.state_dict(), model_save_path)
                best_val_loss = val_loss

    model.load_state_dict(torch.load(model_save_path))
    return model

# %%
encoder_names = [ "resnet34","resnet101","vgg16","vgg19", "efficientnet-b0","efficientnet-b7"]
model_nets=["DeepLabV3","UNET","UNETplus"]
trained_models = {}
num_epochs=20

for encoder_name in encoder_names:
    for model_net in model_nets:
        print(f"Training {model_net} model with encoder {encoder_name}...")
        if model_net=="DeepLabV3" and "vgg" not in encoder_name:
            model = smp.DeepLabV3(
                encoder_name=encoder_name,
                encoder_weights="imagenet",
                in_channels=3,
                classes=1
            )
        elif model_net=="UNET":
            model = smp.Unet(
                encoder_name=encoder_name,
                encoder_weights="imagenet",
                in_channels=3,
                classes=1
            )
        elif model_net=="UNETplus":
            model = smp.UnetPlusPlus(
                encoder_name=encoder_name,
                encoder_weights="imagenet",
                in_channels=3,
                classes=1
            )
        else:
            continue
            
            
        for param in model.encoder.parameters():
            param.requires_grad = False

            # Modify the last layer for segmentation

        model = model.to(device)
        criterion = nn.BCEWithLogitsLoss()
        optimizer = optim.Adam(model.parameters(), lr=0.001)
        model_save_path = f"{model_net}_{encoder_name}.pth"
        trained_model = train_model(model, num_epochs, train_loader, val_loader, criterion, optimizer, model_save_path)
        trained_models[model_net+encoder_name] = trained_model
# Out:
# Training DeepLabV3 model with encoder resnet34...
# Epoch 1/20, Loss: 0.10937970876693726, Validation Loss: 0.09586981790406364
# Validation loss decreased from inf to 0.0959, saving model...
# Epoch 2/20, Loss: 0.10632428526878357, Validation Loss: 0.09366500351045813
# Validation loss decreased from 0.0959 to 0.0937, saving model...
# Epoch 3/20, Loss: 0.10592600703239441, Validation Loss: 0.09388567187956401
# Epoch 4/20, Loss: 0.10698272287845612, Validation Loss: 0.09167201497725078
# Validation loss decreased from 0.0937 to 0.0917, saving model...
# Epoch 5/20, Loss: 0.10742658376693726, Validation Loss: 0.09252103364893369
# Epoch 6/20, Loss: 0.1034507304430008, Validation Loss: 0.08995673832084451
# Validation loss decreased from 0.0917 to 0.0900, saving model...
# Epoch 7/20, Loss: 0.10377804934978485, Validation Loss: 0.0899627126221146
# Epoch 8/20, Loss: 0.10568070411682129, Validation Loss: 0.09013927634805441
# Epoch 9/20, Loss: 0.10423019528388977, Validation Loss: 0.08946704917720386
# Validation loss decreased from 0.0900 to 0.0895, saving model...
# Epoch 10/20, Loss: 0.10458824783563614, Validation Loss: 0.0897852863584246
# Epoch 11/20, Loss: 0.10850216448307037, Validation Loss: 0.09177080355584621
# Epoch 12/20, Loss: 0.10282721370458603, Validation Loss: 0.08889913133212499
# Validation loss decreased from 0.0895 to 0.0889, saving model...
# Epoch 13/20, Loss: 0.10354010760784149, Validation Loss: 0.08879633753427438
# Validation loss decreased from 0.0889 to 0.0888, saving model...
# Epoch 14/20, Loss: 0.10140381753444672, Validation Loss: 0.08870243893138
# Validation loss decreased from 0.0888 to 0.0887, saving model...
# Epoch 15/20, Loss: 0.10938777029514313, Validation Loss: 0.09415357426873275
# Epoch 16/20, Loss: 0.10340206325054169, Validation Loss: 0.08880115672945976
# Epoch 17/20, Loss: 0.10268661379814148, Validation Loss: 0.08845950503434453
# Validation loss decreased from 0.0887 to 0.0885, saving model...
# Epoch 18/20, Loss: 0.10297736525535583, Validation Loss: 0.08826775130416666
# Validation loss decreased from 0.0885 to 0.0883, saving model...
# Epoch 19/20, Loss: 0.10307304561138153, Validation Loss: 0.08825125292475734
# Validation loss decreased from 0.0883 to 0.0883, saving model...
# Epoch 20/20, Loss: 0.10314857959747314, Validation Loss: 0.08826919844640153
# Training UNET model with encoder resnet34...
# Epoch 1/20, Loss: 0.10218454152345657, Validation Loss: 0.09221022895404271
# Validation loss decreased from inf to 0.0922, saving model...
# Epoch 2/20, Loss: 0.10026989877223969, Validation Loss: 0.08745488284954003
# Validation loss decreased from 0.0922 to 0.0875, saving model...
# Epoch 3/20, Loss: 0.09586095064878464, Validation Loss: 0.08611707974757467
# Validation loss decreased from 0.0875 to 0.0861, saving model...
# Epoch 4/20, Loss: 0.09659256786108017, Validation Loss: 0.08584384114614554
# Validation loss decreased from 0.0861 to 0.0858, saving model...
# Epoch 5/20, Loss: 0.09497344493865967, Validation Loss: 0.08061102285448994
# Validation loss decreased from 0.0858 to 0.0806, saving model...
# Epoch 6/20, Loss: 0.09543657302856445, Validation Loss: 0.08041906250374657
# Validation loss decreased from 0.0806 to 0.0804, saving model...
# Epoch 7/20, Loss: 0.09331082552671432, Validation Loss: 0.08074321438159261
# Epoch 8/20, Loss: 0.0924074649810791, Validation Loss: 0.07985893557114261
# Validation loss decreased from 0.0804 to 0.0799, saving model...
# Epoch 9/20, Loss: 0.09322722256183624, Validation Loss: 0.07971351460686751
# Validation loss decreased from 0.0799 to 0.0797, saving model...
# Epoch 10/20, Loss: 0.09332485496997833, Validation Loss: 0.07956740286733423
# Validation loss decreased from 0.0797 to 0.0796, saving model...
# Epoch 11/20, Loss: 0.09216058999300003, Validation Loss: 0.07806164132697242
# Validation loss decreased from 0.0796 to 0.0781, saving model...
# Epoch 12/20, Loss: 0.09278976917266846, Validation Loss: 0.07860377430915833
# Epoch 13/20, Loss: 0.092326819896698, Validation Loss: 0.07942248561552592
# Epoch 14/20, Loss: 0.09272744506597519, Validation Loss: 0.07846179325133562
# Epoch 15/20, Loss: 0.09727781265974045, Validation Loss: 0.08144368949745383
# Epoch 16/20, Loss: 0.09101013094186783, Validation Loss: 0.07813727150538138
# Epoch 17/20, Loss: 0.09086485207080841, Validation Loss: 0.07733291321034942
# Validation loss decreased from 0.0781 to 0.0773, saving model...
# Epoch 18/20, Loss: 0.0917884111404419, Validation Loss: 0.0778286840234484
# Epoch 19/20, Loss: 0.09192179888486862, Validation Loss: 0.0782355380111507
# Epoch 20/20, Loss: 0.0910857766866684, Validation Loss: 0.07727738868977342
# Validation loss decreased from 0.0773 to 0.0773, saving model...
# Training UNETplus model with encoder resnet34...
# Epoch 1/20, Loss: 0.1032383143901825, Validation Loss: 0.09207601020378726
# Validation loss decreased from inf to 0.0921, saving model...
# Epoch 2/20, Loss: 0.09759634733200073, Validation Loss: 0.08394557264234338
# Validation loss decreased from 0.0921 to 0.0839, saving model...
# Epoch 3/20, Loss: 0.09465257823467255, Validation Loss: 0.08168247794466359
# Validation loss decreased from 0.0839 to 0.0817, saving model...
# Epoch 4/20, Loss: 0.09254671633243561, Validation Loss: 0.08003480173647404
# Validation loss decreased from 0.0817 to 0.0800, saving model...
# Epoch 5/20, Loss: 0.09389987587928772, Validation Loss: 0.07917047598000083
# Validation loss decreased from 0.0800 to 0.0792, saving model...
# Epoch 6/20, Loss: 0.09187664836645126, Validation Loss: 0.07917548449976104
# Epoch 7/20, Loss: 0.09219758957624435, Validation Loss: 0.07768815077309098
# Validation loss decreased from 0.0792 to 0.0777, saving model...
# Epoch 8/20, Loss: 0.09068173170089722, Validation Loss: 0.07864144683948585
# Epoch 9/20, Loss: 0.09111467003822327, Validation Loss: 0.07731025320078645
# Validation loss decreased from 0.0777 to 0.0773, saving model...
# Epoch 10/20, Loss: 0.09057052433490753, Validation Loss: 0.07693827152252197
# Validation loss decreased from 0.0773 to 0.0769, saving model...
# Epoch 11/20, Loss: 0.09019207954406738, Validation Loss: 0.07668040000966617
# Validation loss decreased from 0.0769 to 0.0767, saving model...
# Epoch 12/20, Loss: 0.09071453660726547, Validation Loss: 0.07698684850973743
# Epoch 13/20, Loss: 0.09244921803474426, Validation Loss: 0.07792426672364984
# Epoch 14/20, Loss: 0.08996883034706116, Validation Loss: 0.07727583457848855
# Epoch 15/20, Loss: 0.0916808545589447, Validation Loss: 0.07660936032022748
# Validation loss decreased from 0.0767 to 0.0766, saving model...
# Epoch 16/20, Loss: 0.09076106548309326, Validation Loss: 0.07643883422549282
# Validation loss decreased from 0.0766 to 0.0764, saving model...
# Epoch 17/20, Loss: 0.09624733775854111, Validation Loss: 0.08492387192589897
# Epoch 18/20, Loss: 0.09057469666004181, Validation Loss: 0.0766576322327767
# Epoch 19/20, Loss: 0.09056217223405838, Validation Loss: 0.07630261459520885
# Validation loss decreased from 0.0764 to 0.0763, saving model...
# Epoch 20/20, Loss: 0.09073574095964432, Validation Loss: 0.07620199570166213
# Validation loss decreased from 0.0763 to 0.0762, saving model...
# Training DeepLabV3 model with encoder resnet101...
# Epoch 1/20, Loss: 0.10572889447212219, Validation Loss: 0.09395860800785678
# Validation loss decreased from inf to 0.0940, saving model...
# Epoch 2/20, Loss: 0.10507704317569733, Validation Loss: 0.09081330602722508
# Validation loss decreased from 0.0940 to 0.0908, saving model...
# Epoch 3/20, Loss: 0.10121521353721619, Validation Loss: 0.08790415565350226
# Validation loss decreased from 0.0908 to 0.0879, saving model...
# Epoch 4/20, Loss: 0.10292618721723557, Validation Loss: 0.08893120528331824
# Epoch 5/20, Loss: 0.10098439455032349, Validation Loss: 0.08642056331570659
# Validation loss decreased from 0.0879 to 0.0864, saving model...
# Epoch 6/20, Loss: 0.10080168396234512, Validation Loss: 0.0863137918391398
# Validation loss decreased from 0.0864 to 0.0863, saving model...
# Epoch 7/20, Loss: 0.09892631322145462, Validation Loss: 0.08643548829214913
# Epoch 8/20, Loss: 0.10181143879890442, Validation Loss: 0.08569308184087276
# Validation loss decreased from 0.0863 to 0.0857, saving model...
# Epoch 9/20, Loss: 0.09947941452264786, Validation Loss: 0.08547476998397283
# Validation loss decreased from 0.0857 to 0.0855, saving model...
# Epoch 10/20, Loss: 0.1021791622042656, Validation Loss: 0.08722009563020297
# Epoch 11/20, Loss: 0.09913188219070435, Validation Loss: 0.08532677803720747
# Validation loss decreased from 0.0855 to 0.0853, saving model...
# Epoch 12/20, Loss: 0.09918482601642609, Validation Loss: 0.08449189165341002
# Validation loss decreased from 0.0853 to 0.0845, saving model...
# Epoch 13/20, Loss: 0.09923538565635681, Validation Loss: 0.08408626874110528
# Validation loss decreased from 0.0845 to 0.0841, saving model...
# Epoch 14/20, Loss: 0.09850718080997467, Validation Loss: 0.08338678481855563
# Validation loss decreased from 0.0841 to 0.0834, saving model...
# Epoch 15/20, Loss: 0.10180304199457169, Validation Loss: 0.08486992267093488
# Epoch 16/20, Loss: 0.0969187468290329, Validation Loss: 0.0831989673897624
# Validation loss decreased from 0.0834 to 0.0832, saving model...
# Epoch 17/20, Loss: 0.09818954765796661, Validation Loss: 0.08520747521626097
# Epoch 18/20, Loss: 0.1003146544098854, Validation Loss: 0.08391219058207103
# Epoch 19/20, Loss: 0.09825689345598221, Validation Loss: 0.08380771481565066
# Epoch 20/20, Loss: 0.10038609802722931, Validation Loss: 0.08330454304814339
# Training UNET model with encoder resnet101...
# Epoch 1/20, Loss: 0.10288915038108826, Validation Loss: 0.09090914390981197
# Validation loss decreased from inf to 0.0909, saving model...
# Epoch 2/20, Loss: 0.09938366711139679, Validation Loss: 0.08593275996723346
# Validation loss decreased from 0.0909 to 0.0859, saving model...
# Epoch 3/20, Loss: 0.0945824682712555, Validation Loss: 0.08301795247410025
# Validation loss decreased from 0.0859 to 0.0830, saving model...
# Epoch 4/20, Loss: 0.09393242001533508, Validation Loss: 0.08074749380882297
# Validation loss decreased from 0.0830 to 0.0807, saving model...
# Epoch 5/20, Loss: 0.09271959960460663, Validation Loss: 0.07978483528963157
# Validation loss decreased from 0.0807 to 0.0798, saving model...
# Epoch 6/20, Loss: 0.09353522956371307, Validation Loss: 0.07952747547200748
# Validation loss decreased from 0.0798 to 0.0795, saving model...
# Epoch 7/20, Loss: 0.09282813966274261, Validation Loss: 0.07889506460300513
# Validation loss decreased from 0.0795 to 0.0789, saving model...
# Epoch 8/20, Loss: 0.09393024444580078, Validation Loss: 0.07904161033885819
# Epoch 9/20, Loss: 0.09199857711791992, Validation Loss: 0.0779110591060349
# Validation loss decreased from 0.0789 to 0.0779, saving model...
# Epoch 10/20, Loss: 0.09116160124540329, Validation Loss: 0.07737270356821162
# Validation loss decreased from 0.0779 to 0.0774, saving model...
# Epoch 11/20, Loss: 0.09132590889930725, Validation Loss: 0.07778131057109151
# Epoch 12/20, Loss: 0.09056807309389114, Validation Loss: 0.0772110488531845
# Validation loss decreased from 0.0774 to 0.0772, saving model...
# Epoch 13/20, Loss: 0.09104958176612854, Validation Loss: 0.07725742033549718
# Epoch 14/20, Loss: 0.09276781976222992, Validation Loss: 0.07851067025746618
# Epoch 15/20, Loss: 0.0916736051440239, Validation Loss: 0.07800855035228389
# Epoch 16/20, Loss: 0.09097874164581299, Validation Loss: 0.07670092276696648
# Validation loss decreased from 0.0772 to 0.0767, saving model...
# Epoch 17/20, Loss: 0.0906827300786972, Validation Loss: 0.07673747558146715
# Epoch 18/20, Loss: 0.09112183749675751, Validation Loss: 0.07648320748869862
# Validation loss decreased from 0.0767 to 0.0765, saving model...
# Epoch 19/20, Loss: 0.09090293943881989, Validation Loss: 0.07661446223833732
# Epoch 20/20, Loss: 0.09150058031082153, Validation Loss: 0.07678124508155244
# Training UNETplus model with encoder resnet101...
# Epoch 1/20, Loss: 0.10024790465831757, Validation Loss: 0.08807222704802241
# Validation loss decreased from inf to 0.0881, saving model...
# Epoch 2/20, Loss: 0.0968296006321907, Validation Loss: 0.08348411255116973
# Validation loss decreased from 0.0881 to 0.0835, saving model...
# Epoch 3/20, Loss: 0.09720642864704132, Validation Loss: 0.08098084506179605
# Validation loss decreased from 0.0835 to 0.0810, saving model...
# Epoch 4/20, Loss: 0.09251416474580765, Validation Loss: 0.07981881166675261
# Validation loss decreased from 0.0810 to 0.0798, saving model...
# Epoch 5/20, Loss: 0.09252512454986572, Validation Loss: 0.07803615049592086
# Validation loss decreased from 0.0798 to 0.0780, saving model...
# Epoch 6/20, Loss: 0.09221462905406952, Validation Loss: 0.07726585119962692
# Validation loss decreased from 0.0780 to 0.0773, saving model...
# Epoch 7/20, Loss: 0.09086206555366516, Validation Loss: 0.07739529426076583
# Epoch 8/20, Loss: 0.0915454775094986, Validation Loss: 0.07811492894377027
# Epoch 9/20, Loss: 0.09022849798202515, Validation Loss: 0.07728210597165994
# Epoch 10/20, Loss: 0.08979521691799164, Validation Loss: 0.07602224485682589
# Validation loss decreased from 0.0773 to 0.0760, saving model...
# Epoch 11/20, Loss: 0.09011183679103851, Validation Loss: 0.07583475645099368
# Validation loss decreased from 0.0760 to 0.0758, saving model...
# Epoch 12/20, Loss: 0.09046907722949982, Validation Loss: 0.07571135847164052
# Validation loss decreased from 0.0758 to 0.0757, saving model...
# Epoch 13/20, Loss: 0.08937063813209534, Validation Loss: 0.07522873101489884
# Validation loss decreased from 0.0757 to 0.0752, saving model...
# Epoch 14/20, Loss: 0.08860503137111664, Validation Loss: 0.07505975091563803
# Validation loss decreased from 0.0752 to 0.0751, saving model...
# Epoch 15/20, Loss: 0.08831287175416946, Validation Loss: 0.07535130078239101
# Epoch 16/20, Loss: 0.08952205628156662, Validation Loss: 0.07520653373960938
# Epoch 17/20, Loss: 0.09002983570098877, Validation Loss: 0.07553531136363745
# Epoch 18/20, Loss: 0.08958989381790161, Validation Loss: 0.07511700836143323
# Epoch 19/20, Loss: 0.0894666537642479, Validation Loss: 0.07534196680145604
# Epoch 20/20, Loss: 0.08931216597557068, Validation Loss: 0.07490985640989882
# Validation loss decreased from 0.0751 to 0.0749, saving model...
# Training DeepLabV3 model with encoder vgg16...
# Training UNET model with encoder vgg16...
# Epoch 1/20, Loss: 0.10342292487621307, Validation Loss: 0.0899461776550327
# Validation loss decreased from inf to 0.0899, saving model...
# Epoch 2/20, Loss: 0.09830575436353683, Validation Loss: 0.084950637471463
# Validation loss decreased from 0.0899 to 0.0850, saving model...
# Epoch 3/20, Loss: 0.09495961666107178, Validation Loss: 0.08254439303917545
# Validation loss decreased from 0.0850 to 0.0825, saving model...
# Epoch 4/20, Loss: 0.09343848377466202, Validation Loss: 0.081766749200012
# Validation loss decreased from 0.0825 to 0.0818, saving model...
# Epoch 5/20, Loss: 0.09437008202075958, Validation Loss: 0.08240189296858651
# Epoch 6/20, Loss: 0.09465904533863068, Validation Loss: 0.08203918526747397
# Epoch 7/20, Loss: 0.09316631406545639, Validation Loss: 0.08064966529075589
# Validation loss decreased from 0.0818 to 0.0806, saving model...
# Epoch 8/20, Loss: 0.09466052055358887, Validation Loss: 0.08008596327688013
# Validation loss decreased from 0.0806 to 0.0801, saving model...
# Epoch 9/20, Loss: 0.09292317926883698, Validation Loss: 0.0795260960502284
# Validation loss decreased from 0.0801 to 0.0795, saving model...
# Epoch 10/20, Loss: 0.09601528197526932, Validation Loss: 0.08050122923616852
# Epoch 11/20, Loss: 0.09161338955163956, Validation Loss: 0.08003559056669474
# Epoch 12/20, Loss: 0.0930911973118782, Validation Loss: 0.08052254148891994
# Epoch 13/20, Loss: 0.09422829747200012, Validation Loss: 0.0800578435882926
# Epoch 14/20, Loss: 0.09429121017456055, Validation Loss: 0.07953073656452554
# Epoch 15/20, Loss: 0.09513600915670395, Validation Loss: 0.0806436517408916
# Epoch 16/20, Loss: 0.09586486965417862, Validation Loss: 0.08036681969783135
# Epoch 17/20, Loss: 0.09263139218091965, Validation Loss: 0.07954524058316435
# Epoch 18/20, Loss: 0.0929737389087677, Validation Loss: 0.07909871784171887
# Validation loss decreased from 0.0795 to 0.0791, saving model...
# Epoch 19/20, Loss: 0.09862273931503296, Validation Loss: 0.08168654157114881
# Epoch 20/20, Loss: 0.09565096348524094, Validation Loss: 0.08014698925295047
# Training UNETplus model with encoder vgg16...
# Epoch 1/20, Loss: 0.101845882833004, Validation Loss: 0.08737497191343989
# Validation loss decreased from inf to 0.0874, saving model...
# Epoch 2/20, Loss: 0.09557312726974487, Validation Loss: 0.08377867231943778
# Validation loss decreased from 0.0874 to 0.0838, saving model...
# Epoch 3/20, Loss: 0.09363390505313873, Validation Loss: 0.08174125224884067
# Validation loss decreased from 0.0838 to 0.0817, saving model...
# Epoch 4/20, Loss: 0.0912930965423584, Validation Loss: 0.080312260559627
# Validation loss decreased from 0.0817 to 0.0803, saving model...
# Epoch 5/20, Loss: 0.09279210865497589, Validation Loss: 0.08175374647336346
# Epoch 6/20, Loss: 0.09140117466449738, Validation Loss: 0.07962407930088895
# Validation loss decreased from 0.0803 to 0.0796, saving model...
# Epoch 7/20, Loss: 0.09103319048881531, Validation Loss: 0.0790866067899125
# Validation loss decreased from 0.0796 to 0.0791, saving model...
# Epoch 8/20, Loss: 0.09146294742822647, Validation Loss: 0.07937396597117186
# Epoch 9/20, Loss: 0.0904594287276268, Validation Loss: 0.08035837619432382
# Epoch 10/20, Loss: 0.09629343450069427, Validation Loss: 0.08011812237756592
# Epoch 11/20, Loss: 0.10160869359970093, Validation Loss: 0.0868191873388631
# Epoch 12/20, Loss: 0.08968973159790039, Validation Loss: 0.07787752989679575
# Validation loss decreased from 0.0791 to 0.0779, saving model...
# Epoch 13/20, Loss: 0.09030777961015701, Validation Loss: 0.07796910258808307
# Epoch 14/20, Loss: 0.09170539677143097, Validation Loss: 0.07820239596601043
# Epoch 15/20, Loss: 0.09161268919706345, Validation Loss: 0.07851176163447755
# Epoch 16/20, Loss: 0.09133347868919373, Validation Loss: 0.07807522932333606
# Epoch 17/20, Loss: 0.09170536696910858, Validation Loss: 0.0785177308799965
# Epoch 18/20, Loss: 0.09202809631824493, Validation Loss: 0.07926476919757468
# Epoch 19/20, Loss: 0.09206514060497284, Validation Loss: 0.0793521384309445
# Epoch 20/20, Loss: 0.09147501736879349, Validation Loss: 0.07894629998398679
# Training DeepLabV3 model with encoder vgg19...
# Training UNET model with encoder vgg19...
# Epoch 1/20, Loss: 0.11268914490938187, Validation Loss: 0.1019749276872192
# Validation loss decreased from inf to 0.1020, saving model...
# Epoch 2/20, Loss: 0.10017645359039307, Validation Loss: 0.08850492497107812
# Validation loss decreased from 0.1020 to 0.0885, saving model...
# Epoch 3/20, Loss: 0.09540923684835434, Validation Loss: 0.08470010983624629
# Validation loss decreased from 0.0885 to 0.0847, saving model...
# Epoch 4/20, Loss: 0.09518550336360931, Validation Loss: 0.08360219720218863
# Validation loss decreased from 0.0847 to 0.0836, saving model...
# Epoch 5/20, Loss: 0.09691770374774933, Validation Loss: 0.08291871672762292
# Validation loss decreased from 0.0836 to 0.0829, saving model...
# Epoch 6/20, Loss: 0.09463810175657272, Validation Loss: 0.08137575324092593
# Validation loss decreased from 0.0829 to 0.0814, saving model...
# Epoch 7/20, Loss: 0.09331278502941132, Validation Loss: 0.08230969256588391
# Epoch 8/20, Loss: 0.09373927861452103, Validation Loss: 0.08083231733845812
# Validation loss decreased from 0.0814 to 0.0808, saving model...
# Epoch 9/20, Loss: 0.09366267919540405, Validation Loss: 0.08029551338404417
# Validation loss decreased from 0.0808 to 0.0803, saving model...
# Epoch 10/20, Loss: 0.09289824962615967, Validation Loss: 0.07981834028448377
# Validation loss decreased from 0.0803 to 0.0798, saving model...
# Epoch 11/20, Loss: 0.092758409678936, Validation Loss: 0.07999428335045065
# Epoch 12/20, Loss: 0.09306511282920837, Validation Loss: 0.0797453819374953
# Validation loss decreased from 0.0798 to 0.0797, saving model...
# Epoch 13/20, Loss: 0.09185826778411865, Validation Loss: 0.07937802667064327
# Validation loss decreased from 0.0797 to 0.0794, saving model...
# Epoch 14/20, Loss: 0.0925893485546112, Validation Loss: 0.08033210451581649
# Epoch 15/20, Loss: 0.09336941689252853, Validation Loss: 0.08070293215236493
# Epoch 16/20, Loss: 0.09216342866420746, Validation Loss: 0.07939825765788555
# Epoch 17/20, Loss: 0.09295563399791718, Validation Loss: 0.0791932839368071
# Validation loss decreased from 0.0794 to 0.0792, saving model...
# Epoch 18/20, Loss: 0.09690692275762558, Validation Loss: 0.08185158936040741
# Epoch 19/20, Loss: 0.09254446625709534, Validation Loss: 0.07968363884304251
# Epoch 20/20, Loss: 0.09383518993854523, Validation Loss: 0.07980358307915074
# Training UNETplus model with encoder vgg19...
# Epoch 1/20, Loss: 0.10048448294401169, Validation Loss: 0.08690909894981555
# Validation loss decreased from inf to 0.0869, saving model...
# Epoch 2/20, Loss: 0.09651148319244385, Validation Loss: 0.08389872405678034
# Validation loss decreased from 0.0869 to 0.0839, saving model...
# Epoch 3/20, Loss: 0.09334856271743774, Validation Loss: 0.08167991028832537
# Validation loss decreased from 0.0839 to 0.0817, saving model...
# Epoch 4/20, Loss: 0.09220448136329651, Validation Loss: 0.0802308154691543
# Validation loss decreased from 0.0817 to 0.0802, saving model...
# Epoch 5/20, Loss: 0.09145030379295349, Validation Loss: 0.07967946146215711
# Validation loss decreased from 0.0802 to 0.0797, saving model...
# Epoch 6/20, Loss: 0.09313181042671204, Validation Loss: 0.07973033123250518
# Epoch 7/20, Loss: 0.0922526866197586, Validation Loss: 0.08121559356472322
# Epoch 8/20, Loss: 0.0914703905582428, Validation Loss: 0.07866634441805738
# Validation loss decreased from 0.0797 to 0.0787, saving model...
# Epoch 9/20, Loss: 0.09156964719295502, Validation Loss: 0.07885398130331721
# Epoch 10/20, Loss: 0.09070467948913574, Validation Loss: 0.07940031282071557
# Epoch 11/20, Loss: 0.09236401319503784, Validation Loss: 0.0792156874335238
# Epoch 12/20, Loss: 0.09166237711906433, Validation Loss: 0.07917749256427799
# Epoch 13/20, Loss: 0.09029646962881088, Validation Loss: 0.07840986802641835
# Validation loss decreased from 0.0787 to 0.0784, saving model...
# Epoch 14/20, Loss: 0.09358549118041992, Validation Loss: 0.08132366836071014
# Epoch 15/20, Loss: 0.08955885469913483, Validation Loss: 0.07895977555641107
# Epoch 16/20, Loss: 0.09116997569799423, Validation Loss: 0.07841283295835767
# Epoch 17/20, Loss: 0.09126649796962738, Validation Loss: 0.07824391951518399
# Validation loss decreased from 0.0784 to 0.0782, saving model...
# Epoch 18/20, Loss: 0.09125447273254395, Validation Loss: 0.07963270587580544
# Epoch 19/20, Loss: 0.09738278388977051, Validation Loss: 0.08382966914879424
# Epoch 20/20, Loss: 0.09081418067216873, Validation Loss: 0.07971167098730803
# Training DeepLabV3 model with encoder efficientnet-b0...
# Epoch 1/20, Loss: 0.12974807620048523, Validation Loss: 0.10640973837247916
# Validation loss decreased from inf to 0.1064, saving model...
# Epoch 2/20, Loss: 0.11765661090612411, Validation Loss: 0.09722640391971384
# Validation loss decreased from 0.1064 to 0.0972, saving model...
# Epoch 3/20, Loss: 0.10863716900348663, Validation Loss: 0.0931186747870275
# Validation loss decreased from 0.0972 to 0.0931, saving model...
# Epoch 4/20, Loss: 0.10802953690290451, Validation Loss: 0.09174225372927529
# Validation loss decreased from 0.0931 to 0.0917, saving model...
# Epoch 5/20, Loss: 0.10909023880958557, Validation Loss: 0.09186563028820924
# Epoch 6/20, Loss: 0.10711890459060669, Validation Loss: 0.09153467230498791
# Validation loss decreased from 0.0917 to 0.0915, saving model...
# Epoch 7/20, Loss: 0.10609862208366394, Validation Loss: 0.09059891503836427
# Validation loss decreased from 0.0915 to 0.0906, saving model...
# Epoch 8/20, Loss: 0.10551415383815765, Validation Loss: 0.09074522661311286
# Epoch 9/20, Loss: 0.10501132905483246, Validation Loss: 0.09086046128400735
# Epoch 10/20, Loss: 0.10961100459098816, Validation Loss: 0.09049043857625552
# Validation loss decreased from 0.0906 to 0.0905, saving model...
# Epoch 11/20, Loss: 0.10908644646406174, Validation Loss: 0.09004636853933334
# Validation loss decreased from 0.0905 to 0.0900, saving model...
# Epoch 12/20, Loss: 0.10594943910837173, Validation Loss: 0.09002481454185077
# Validation loss decreased from 0.0900 to 0.0900, saving model...
# Epoch 13/20, Loss: 0.10555069893598557, Validation Loss: 0.08973549040300506
# Validation loss decreased from 0.0900 to 0.0897, saving model...
# Epoch 14/20, Loss: 0.10873633623123169, Validation Loss: 0.08975076435932092
# Epoch 15/20, Loss: 0.10516168177127838, Validation Loss: 0.08978062788290637
# Epoch 16/20, Loss: 0.10665859282016754, Validation Loss: 0.08977090593959604
# Epoch 17/20, Loss: 0.10902455449104309, Validation Loss: 0.09006354558680739
# Epoch 18/20, Loss: 0.10783163458108902, Validation Loss: 0.08983043714293412
# Epoch 19/20, Loss: 0.10458540171384811, Validation Loss: 0.08929395702268396
# Validation loss decreased from 0.0897 to 0.0893, saving model...
# Epoch 20/20, Loss: 0.10554870218038559, Validation Loss: 0.08931246772408485
# Training UNET model with encoder efficientnet-b0...
# Epoch 1/20, Loss: 0.11182056367397308, Validation Loss: 0.09453031713409084
# Validation loss decreased from inf to 0.0945, saving model...
# Epoch 2/20, Loss: 0.10052069276571274, Validation Loss: 0.08475243845688445
# Validation loss decreased from 0.0945 to 0.0848, saving model...
# Epoch 3/20, Loss: 0.09625449776649475, Validation Loss: 0.08285418179418359
# Validation loss decreased from 0.0848 to 0.0829, saving model...
# Epoch 4/20, Loss: 0.093132883310318, Validation Loss: 0.08087012517665114
# Validation loss decreased from 0.0829 to 0.0809, saving model...
# Epoch 5/20, Loss: 0.09211137145757675, Validation Loss: 0.07965938028480325
# Validation loss decreased from 0.0809 to 0.0797, saving model...
# Epoch 6/20, Loss: 0.09135029464960098, Validation Loss: 0.07983912221555199
# Epoch 7/20, Loss: 0.091289222240448, Validation Loss: 0.07831675572586912
# Validation loss decreased from 0.0797 to 0.0783, saving model...
# Epoch 8/20, Loss: 0.09076118469238281, Validation Loss: 0.0779858021331685
# Validation loss decreased from 0.0783 to 0.0780, saving model...
# Epoch 9/20, Loss: 0.09050926566123962, Validation Loss: 0.07738643751612731
# Validation loss decreased from 0.0780 to 0.0774, saving model...
# Epoch 10/20, Loss: 0.09060825407505035, Validation Loss: 0.07726168712334973
# Validation loss decreased from 0.0774 to 0.0773, saving model...
# Epoch 11/20, Loss: 0.0903107076883316, Validation Loss: 0.07672462066901582
# Validation loss decreased from 0.0773 to 0.0767, saving model...
# Epoch 12/20, Loss: 0.08983410894870758, Validation Loss: 0.07646730103130851
# Validation loss decreased from 0.0767 to 0.0765, saving model...
# Epoch 13/20, Loss: 0.08980975300073624, Validation Loss: 0.07674457186034747
# Epoch 14/20, Loss: 0.090272456407547, Validation Loss: 0.0763347784855536
# Validation loss decreased from 0.0765 to 0.0763, saving model...
# Epoch 15/20, Loss: 0.08986910432577133, Validation Loss: 0.07645203519080367
# Epoch 16/20, Loss: 0.08907133340835571, Validation Loss: 0.07596731092780828
# Validation loss decreased from 0.0763 to 0.0760, saving model...
# Epoch 17/20, Loss: 0.08969882130622864, Validation Loss: 0.07600741793534585
# Epoch 18/20, Loss: 0.08992656320333481, Validation Loss: 0.07617307786962815
# Epoch 19/20, Loss: 0.08978953957557678, Validation Loss: 0.07626801383282457
# Epoch 20/20, Loss: 0.0891779214143753, Validation Loss: 0.07583986089697906
# Validation loss decreased from 0.0760 to 0.0758, saving model...
# Training UNETplus model with encoder efficientnet-b0...
# Epoch 1/20, Loss: 0.10705465078353882, Validation Loss: 0.09543269553354808
# Validation loss decreased from inf to 0.0954, saving model...
# Epoch 2/20, Loss: 0.09992071241140366, Validation Loss: 0.08645467553287745
# Validation loss decreased from 0.0954 to 0.0865, saving model...
# Epoch 3/20, Loss: 0.09429503977298737, Validation Loss: 0.08241504923041378
# Validation loss decreased from 0.0865 to 0.0824, saving model...
# Epoch 4/20, Loss: 0.09334161877632141, Validation Loss: 0.08016882464289665
# Validation loss decreased from 0.0824 to 0.0802, saving model...
# Epoch 5/20, Loss: 0.09385736286640167, Validation Loss: 0.07970349437424115
# Validation loss decreased from 0.0802 to 0.0797, saving model...
# Epoch 6/20, Loss: 0.09146064519882202, Validation Loss: 0.07869992205607039
# Validation loss decreased from 0.0797 to 0.0787, saving model...
# Epoch 7/20, Loss: 0.09170183539390564, Validation Loss: 0.0803235424682498
# Epoch 8/20, Loss: 0.09109631180763245, Validation Loss: 0.07737135275134019
# Validation loss decreased from 0.0787 to 0.0774, saving model...
# Epoch 9/20, Loss: 0.09037825465202332, Validation Loss: 0.07718190550804138
# Validation loss decreased from 0.0774 to 0.0772, saving model...
# Epoch 10/20, Loss: 0.08981814235448837, Validation Loss: 0.07698538580111094
# Validation loss decreased from 0.0772 to 0.0770, saving model...
# Epoch 11/20, Loss: 0.08999481797218323, Validation Loss: 0.07679493978087391
# Validation loss decreased from 0.0770 to 0.0768, saving model...
# Epoch 12/20, Loss: 0.08951306343078613, Validation Loss: 0.0770429295620748
# Epoch 13/20, Loss: 0.08988921344280243, Validation Loss: 0.07649589915360723
# Validation loss decreased from 0.0768 to 0.0765, saving model...
# Epoch 14/20, Loss: 0.08888593316078186, Validation Loss: 0.07620331764753376
# Validation loss decreased from 0.0765 to 0.0762, saving model...
# Epoch 15/20, Loss: 0.08917729556560516, Validation Loss: 0.07606791212622609
# Validation loss decreased from 0.0762 to 0.0761, saving model...
# Epoch 16/20, Loss: 0.08973545581102371, Validation Loss: 0.0759432917194707
# Validation loss decreased from 0.0761 to 0.0759, saving model...
# Epoch 17/20, Loss: 0.0891062468290329, Validation Loss: 0.07767109160444566
# Epoch 18/20, Loss: 0.0896664634346962, Validation Loss: 0.07669060690594572
# Epoch 19/20, Loss: 0.08942384272813797, Validation Loss: 0.07575940327452761
# Validation loss decreased from 0.0759 to 0.0758, saving model...
# Epoch 20/20, Loss: 0.08854401111602783, Validation Loss: 0.07566874394459384
# Validation loss decreased from 0.0758 to 0.0757, saving model...
# Training DeepLabV3 model with encoder efficientnet-b7...
# Epoch 1/20, Loss: 0.11864671111106873, Validation Loss: 0.10152203190539565
# Validation loss decreased from inf to 0.1015, saving model...
# Epoch 2/20, Loss: 0.1120486855506897, Validation Loss: 0.096246387809515
# Validation loss decreased from 0.1015 to 0.0962, saving model...
# Epoch 3/20, Loss: 0.11077110469341278, Validation Loss: 0.09532239421137742
# Validation loss decreased from 0.0962 to 0.0953, saving model...
# Epoch 4/20, Loss: 0.10777074098587036, Validation Loss: 0.09521186857351235
# Validation loss decreased from 0.0953 to 0.0952, saving model...
# Epoch 5/20, Loss: 0.11024818569421768, Validation Loss: 0.09449613333812781
# Validation loss decreased from 0.0952 to 0.0945, saving model...
# Epoch 6/20, Loss: 0.10875660181045532, Validation Loss: 0.09371108002960682
# Validation loss decreased from 0.0945 to 0.0937, saving model...
# Epoch 7/20, Loss: 0.1097089946269989, Validation Loss: 0.09346389078668185
# Validation loss decreased from 0.0937 to 0.0935, saving model...
# Epoch 8/20, Loss: 0.10709747672080994, Validation Loss: 0.09353281344686236
# Epoch 9/20, Loss: 0.10773208737373352, Validation Loss: 0.09261971552457128
# Validation loss decreased from 0.0935 to 0.0926, saving model...
# Epoch 10/20, Loss: 0.105806864798069, Validation Loss: 0.09279268687324864
# Epoch 11/20, Loss: 0.10932660102844238, Validation Loss: 0.09265002235770226
# Epoch 12/20, Loss: 0.10788089036941528, Validation Loss: 0.09220049104520253
# Validation loss decreased from 0.0926 to 0.0922, saving model...
# Epoch 13/20, Loss: 0.10879965126514435, Validation Loss: 0.09240989866001266
# Epoch 14/20, Loss: 0.11252061277627945, Validation Loss: 0.09281813140426363
# Epoch 15/20, Loss: 0.10975278913974762, Validation Loss: 0.09287242697817939
# Epoch 16/20, Loss: 0.10767143964767456, Validation Loss: 0.0926581799451794
# Epoch 17/20, Loss: 0.10767491161823273, Validation Loss: 0.09214976988732815
# Validation loss decreased from 0.0922 to 0.0921, saving model...
# Epoch 18/20, Loss: 0.10728977620601654, Validation Loss: 0.09195863083004951
# Validation loss decreased from 0.0921 to 0.0920, saving model...
# Epoch 19/20, Loss: 0.10823012888431549, Validation Loss: 0.09223219486219543
# Epoch 20/20, Loss: 0.10696358978748322, Validation Loss: 0.09225159085222653
# Training UNET model with encoder efficientnet-b7...
# Epoch 1/20, Loss: 0.10295814275741577, Validation Loss: 0.09170397956456457
# Validation loss decreased from inf to 0.0917, saving model...
# Epoch 2/20, Loss: 0.09847070276737213, Validation Loss: 0.08555723660226379
# Validation loss decreased from 0.0917 to 0.0856, saving model...
# Epoch 3/20, Loss: 0.09609334915876389, Validation Loss: 0.08181479014456272
# Validation loss decreased from 0.0856 to 0.0818, saving model...
# Epoch 4/20, Loss: 0.09334753453731537, Validation Loss: 0.07942723908594676
# Validation loss decreased from 0.0818 to 0.0794, saving model...
# Epoch 5/20, Loss: 0.09150449931621552, Validation Loss: 0.07810448788638626
# Validation loss decreased from 0.0794 to 0.0781, saving model...
# Epoch 6/20, Loss: 0.09176361560821533, Validation Loss: 0.07770715893379279
# Validation loss decreased from 0.0781 to 0.0777, saving model...
# Epoch 7/20, Loss: 0.09127552807331085, Validation Loss: 0.07714076672813722
# Validation loss decreased from 0.0777 to 0.0771, saving model...
# Epoch 8/20, Loss: 0.09070076048374176, Validation Loss: 0.07710049061902932
# Validation loss decreased from 0.0771 to 0.0771, saving model...
# Epoch 9/20, Loss: 0.09080037474632263, Validation Loss: 0.07706500217318535
# Validation loss decreased from 0.0771 to 0.0771, saving model...
# Epoch 10/20, Loss: 0.09093105792999268, Validation Loss: 0.07624383350568158
# Validation loss decreased from 0.0771 to 0.0762, saving model...
# Epoch 11/20, Loss: 0.0901678055524826, Validation Loss: 0.07666782209915775
# Epoch 12/20, Loss: 0.09207410365343094, Validation Loss: 0.07687341940722295
# Epoch 13/20, Loss: 0.09098797291517258, Validation Loss: 0.07645948923059873
# Epoch 14/20, Loss: 0.09064920246601105, Validation Loss: 0.07602085266262293
# Validation loss decreased from 0.0762 to 0.0760, saving model...
# Epoch 15/20, Loss: 0.08970960974693298, Validation Loss: 0.07563682778605393
# Validation loss decreased from 0.0760 to 0.0756, saving model...
# Epoch 16/20, Loss: 0.09160366654396057, Validation Loss: 0.07611018432570356
# Epoch 17/20, Loss: 0.09102697670459747, Validation Loss: 0.07549887749233417
# Validation loss decreased from 0.0756 to 0.0755, saving model...
# Epoch 18/20, Loss: 0.09146802127361298, Validation Loss: 0.07558069311614547
# Epoch 19/20, Loss: 0.09042070060968399, Validation Loss: 0.07549141493758985
# Validation loss decreased from 0.0755 to 0.0755, saving model...
# Epoch 20/20, Loss: 0.0900011956691742, Validation Loss: 0.07518239585416657
# Validation loss decreased from 0.0755 to 0.0752, saving model...
# Training UNETplus model with encoder efficientnet-b7...
# Epoch 1/20, Loss: 0.10587916523218155, Validation Loss: 0.09143855755350419
# Validation loss decreased from inf to 0.0914, saving model...
# Epoch 2/20, Loss: 0.09598259627819061, Validation Loss: 0.08318446257284709
# Validation loss decreased from 0.0914 to 0.0832, saving model...
# Epoch 3/20, Loss: 0.09523282945156097, Validation Loss: 0.08053692031119551
# Validation loss decreased from 0.0832 to 0.0805, saving model...
# Epoch 4/20, Loss: 0.09270503371953964, Validation Loss: 0.07852327677288226
# Validation loss decreased from 0.0805 to 0.0785, saving model...
# Epoch 5/20, Loss: 0.09155610203742981, Validation Loss: 0.07738819239395005
# Validation loss decreased from 0.0785 to 0.0774, saving model...
# Epoch 6/20, Loss: 0.09238219261169434, Validation Loss: 0.0770402674430183
# Validation loss decreased from 0.0774 to 0.0770, saving model...
# Epoch 7/20, Loss: 0.0916472002863884, Validation Loss: 0.07644838759941715
# Validation loss decreased from 0.0770 to 0.0764, saving model...
# Epoch 8/20, Loss: 0.09110437333583832, Validation Loss: 0.0763648928010038
# Validation loss decreased from 0.0764 to 0.0764, saving model...
# Epoch 9/20, Loss: 0.09049024432897568, Validation Loss: 0.07702477010233062
# Epoch 10/20, Loss: 0.09026411175727844, Validation Loss: 0.07572524169726032
# Validation loss decreased from 0.0764 to 0.0757, saving model...
# Epoch 11/20, Loss: 0.08996807038784027, Validation Loss: 0.07622865148420845
# Epoch 12/20, Loss: 0.09234605729579926, Validation Loss: 0.07639009598642588
# Epoch 13/20, Loss: 0.08975189179182053, Validation Loss: 0.07604080105998687
# Epoch 14/20, Loss: 0.0896139144897461, Validation Loss: 0.07521036959120206
# Validation loss decreased from 0.0757 to 0.0752, saving model...
# Epoch 15/20, Loss: 0.0902295634150505, Validation Loss: 0.07538086402096919
# Epoch 16/20, Loss: 0.08927173167467117, Validation Loss: 0.0752435542110886
# Epoch 17/20, Loss: 0.08940772712230682, Validation Loss: 0.07508752654705729
# Validation loss decreased from 0.0752 to 0.0751, saving model...
# Epoch 18/20, Loss: 0.08940009772777557, Validation Loss: 0.07574079119201217
# Epoch 19/20, Loss: 0.09115041047334671, Validation Loss: 0.07551321906170674
# Epoch 20/20, Loss: 0.09099260717630386, Validation Loss: 0.07537577434309892

# %%
# class ViTUnet(nn.Module):
#     def __init__(self, vit_model_name, num_classes):
#         super(ViTUnet, self).__init__()
#         self.vit = timm.create_model(vit_model_name, pretrained=True)
        
#         # self.decoder = UnetDecoder(
#         #     encoder_channels=(self.vit.head.in_features, 512, 256, 128, 64),
#         #     decoder_channels=(256, 128, 64, 32, 16),
#         #     final_channels=num_classes,
#         #     use_batchnorm=True
#         # )
#         self.decoder = UnetDecoder(in_channels=self.vit.head.in_features, out_channels=num_classes, use_batchnorm=True)
#         self.vit.head = nn.Identity()
#         self.segmentation_head = SegmentationHead(
#             in_channels=16,
#             out_channels=num_classes,
#             activation='sigmoid',
#             kernel_size=3
#         )

#     def forward(self, x):
#         features = self.vit(x)
#         x = self.decoder([features])
#         x = self.segmentation_head(x)
#         return x

# vit_model_names = ["vit_base_patch16_224", "vit_base_patch32_224", "vit_large_patch16_224", "vit_large_patch32_224"]
# for vit_model_name in vit_model_names:
#     print(f"Training model with Vision Transformer {vit_model_name}...")
#     model = ViTUnet(vit_model_name, num_classes=1)
#     model = model.to(device)
#     criterion = nn.BCEWithLogitsLoss()
#     optimizer = optim.Adam(model.parameters(), lr=0.001)
#     model_save_path = f"unet_{vit_model_name}.pth"
#     trained_model = train_model(model, num_epochs, train_loader, val_loader, criterion, optimizer, model_save_path)
#     trained_models[vit_model_name] = trained_model

# %%
# model.load_state_dict(torch.load(model_save_path))
# model = model.to(device)
# model.eval()



def tensor_to_image(tensor):
    image = tensor.cpu().numpy().transpose((1, 2, 0))
    return (image * 255).astype(np.uint8)

def tensor_to_mask(tensor):
    mask = tensor.cpu().numpy().squeeze()
    # print(mask)
    return mask

def compute_scores(y_true, y_pred, threshold=0.1):
  
    y_true = (y_true > threshold).astype(np.uint8).flatten()
    y_pred = (y_pred > threshold).astype(np.uint8).flatten()

    accuracy = accuracy_score(y_true, y_pred)
    precision = precision_score(y_true, y_pred)
    recall = recall_score(y_true, y_pred)
    f1 = f1_score(y_true, y_pred)
    iou=iou_score(y_true, y_pred)
    dice=dice_coefficient(y_true, y_pred)

    return accuracy,precision,recall,f1,iou,dice

def iou_score(y_true, y_pred):
    intersection = np.logical_and(y_true, y_pred).sum()
    union = np.logical_or(y_true, y_pred).sum()
    return intersection / union

def dice_coefficient(y_true, y_pred):
    intersection = np.logical_and(y_true, y_pred).sum()
    return (2 * intersection) / (y_true.sum() + y_pred.sum())

def evaluate_models(trained_models, val_loader, threshold):
    evaluation_results = {}
    
    for model_name, model in trained_models.items():
        model.eval()
        accuracies, precisions, recalls, f1_scores, ious, dice_coeffs = [], [], [], [], [], []

        with torch.no_grad():
            for images, masks in val_loader:
                images = images.to(device)
                masks = masks.to(device)

                preds = torch.sigmoid(model(images))

                preds = (preds > threshold).float()
                masks = (masks > threshold).float()


                accuracy,precision,recall,f1,iou,dice = compute_scores(masks.cpu().numpy(), preds.cpu().numpy(),threshold)
           
                accuracies.append(accuracy)
                precisions.append(precision)
                recalls.append(recall)
                f1_scores.append(f1)
                ious.append(iou)
                dice_coeffs.append(dice)

        evaluation_results[model_name] = {
            "Accuracy": np.mean(accuracies),
            "Precision": np.mean(precisions),
            "Recall": np.mean(recalls),
            "F1-score": np.mean(f1_scores),
            "IoU": np.mean(ious),
            "Dice": np.mean(dice_coeffs)
        }

    return evaluation_results

threshold = 0.1
evaluation_results = evaluate_models(trained_models, val_loader, threshold)

# %%
 # Plot evaluation results
encoder_names_with_vit = trained_models.keys() 
print(encoder_names_with_vit)
metrics = ["Accuracy", "Precision", "Recall", "F1-score", "IoU", "Dice"]

fig, axs = plt.subplots(len(metrics), 1, figsize=(12, 30))
for i, metric in enumerate(metrics):
    axs[i].plot(encoder_names_with_vit, [evaluation_results[name][metric] for name in encoder_names_with_vit], label=metric, marker='o')
    axs[i].legend()
    axs[i].set_xlabel("Model Name")
    axs[i].set_ylabel(metric)
    axs[i].set_title(f"Comparison of {metric} for Different Models")
    axs[i].tick_params(axis='x', rotation=90)

plt.tight_layout()
plt.show()
# Out:
# dict_keys(['DeepLabV3resnet34', 'UNETresnet34', 'UNETplusresnet34', 'DeepLabV3resnet101', 'UNETresnet101', 'UNETplusresnet101', 'UNETvgg16', 'UNETplusvgg16', 'UNETvgg19', 'UNETplusvgg19', 'DeepLabV3efficientnet-b0', 'UNETefficientnet-b0', 'UNETplusefficientnet-b0', 'DeepLabV3efficientnet-b7', 'UNETefficientnet-b7', 'UNETplusefficientnet-b7'])

# %%
best_metric = 'IoU'  # You can change this to IoU, F1-score, etc.

# Sort the models based on the best_metric in descending order
sorted_models = sorted(evaluation_results.items(), key=lambda x: x[1][best_metric], reverse=True)

# Get the best model name and its corresponding evaluation metrics
best_model_name, best_model_metrics = sorted_models[0]

print(f"Best model based on {best_metric}: {best_model_name}")
print(f"Evaluation metrics for the best model: {best_model_metrics}")
# Out:
# Best model based on IoU: UNETplusresnet101
# Evaluation metrics for the best model: {'Accuracy': 0.9730960300990513, 'Precision': 0.9289775489808496, 'Recall': 0.8963638287577661, 'F1-score': 0.9122071505058884, 'IoU': 0.8391734521538917, 'Dice': 0.9122071505058883}

# %%
model=trained_models[best_model_name]
with torch.no_grad():
    for images, masks in val_loader:
        images = images.to(device)
        masks = masks.to(device)

        preds = torch.sigmoid(model(images))
        # preds = model(images)

        preds = (preds > threshold).float()
        masks = (masks > threshold).float()

num_images_to_plot = min(5, len(images))
fig, ax = plt.subplots(num_images_to_plot, 3, figsize=(12, num_images_to_plot*4))

for i in range(num_images_to_plot):
    ax[i, 0].imshow(tensor_to_image(images[i]))
    ax[i, 0].set_title("Original Image")
    ax[i, 0].axis("off")

    ax[i, 1].imshow(tensor_to_mask(masks[i]), cmap="gray")
    ax[i, 1].set_title("Ground Truth Mask")
    ax[i, 1].axis("off")

    ax[i, 2].imshow(tensor_to_mask(preds[i]), cmap="gray")
    ax[i, 2].set_title("Predicted Mask")
    ax[i, 2].axis("off")

plt.show()
